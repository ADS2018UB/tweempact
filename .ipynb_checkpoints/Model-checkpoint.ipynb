# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from __future__ import division
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn import model_selection
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from __future__ import division
from sklearn.metrics import mean_squared_error, r2_score


#llegeixo l'arxiu sense les paraules que nomes apareixien una vegada

df = pd.read_csv('datasets/clean_authors.csv') 
df = df.drop('Unnamed: 0',axis=1)
df.head(5)
# Out:
#    RT_l10      sd_RT  FC_l10       sd_FC    FC   RT  protected  \
# 0     0.4   0.489898     1.7    3.796051   0.0  0.0        0.0
# 1     8.4  16.805951    76.1  127.668673  25.0  3.0        0.0
# 2     0.2   0.400000     2.5    3.442383   0.0  0.0        0.0
# 3     0.0   0.000000     0.3    0.458258   0.0  0.0        0.0
# 4     3.6   6.711185     2.8    5.015974   0.0  1.0        0.0
#
#    followers_count  friends_count  listed_count  favourites_count  \
# 0           5386.0         3861.0         304.0           15325.0
# 1          24075.0          100.0          96.0           20991.0
# 2            297.0          190.0           9.0            6257.0
# 3            557.0          650.0          19.0            6218.0
# 4          54626.0         4640.0        1646.0             405.0
#
#    statuses_count
# 0         85493.0
# 1         10496.0
# 2         28572.0
# 3          5983.0
# 4         70865.0

# %%
df.describe()
# Out:
#            RT_l10        sd_RT      FC_l10        sd_FC          FC  \
# count  186.000000   186.000000  186.000000   186.000000  186.000000
# mean     6.440860     9.766250   12.211290    17.577921    4.236559
# std     45.892884    83.493260   77.018382   136.465272   20.852842
# min      0.000000     0.000000    0.000000     0.000000    0.000000
# 25%      0.000000     0.000000    0.500000     0.500000    0.000000
# 50%      0.200000     0.400000    1.000000     1.159499    0.500000
# 75%      0.600000     0.921954    2.575000     3.433256    2.000000
# max    507.700000  1080.126201  831.800000  1778.543325  251.000000
#
#                RT  protected  followers_count  friends_count  listed_count  \
# count  186.000000      186.0       186.000000     186.000000    186.000000
# mean     1.838710        0.0      3348.983871    1089.940860     44.446237
# std     10.485295        0.0      9902.605948    4944.883376    138.232706
# min      0.000000        0.0         5.000000       5.000000      0.000000
# 25%      0.000000        0.0       169.750000     189.000000      1.000000
# 50%      0.000000        0.0       504.000000     410.500000      6.000000
# 75%      0.000000        0.0      2014.250000     808.250000     35.750000
# max    115.000000        0.0     90497.000000   66900.000000   1646.000000
#
#        favourites_count  statuses_count
# count        186.000000      186.000000
# mean       12415.741935    22349.720430
# std        29546.877792    44035.323379
# min            0.000000       26.000000
# 25%          448.500000     2696.250000
# 50%         3536.500000     8663.000000
# 75%        13323.000000    24611.750000
# max       247616.000000   392307.000000

# %% [markdown]
# through the main statisticians we observe that there are very extreme values ​​in almost all the variables

# %%
fig, axs = plt.subplots(3, 4)
axs[0, 0].boxplot(df[df.columns[0,]])
axs[0, 1].boxplot(df[df.columns[1,]])
axs[0, 2].boxplot(df[df.columns[2,]])
axs[1, 0].boxplot(df[df.columns[3,]])
axs[1, 1].boxplot(df[df.columns[4,]])
axs[1, 2].boxplot(df[df.columns[5,]])
axs[2, 2].boxplot(df[df.columns[6,]])
axs[0, 3].boxplot(df[df.columns[7,]])
axs[1, 3].boxplot(df[df.columns[8,]])
axs[2, 3].boxplot(df[df.columns[9,]])
axs[2, 0].boxplot(df[df.columns[10,]])
axs[2, 1].boxplot(df[df.columns[11,]])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c1ed5d2b0>,
#   <matplotlib.lines.Line2D at 0x1c1ed5d748>],
#  'caps': [<matplotlib.lines.Line2D at 0x1c1ed5db70>,
#   <matplotlib.lines.Line2D at 0x1c1ed5df98>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1c1ed5d160>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c1ed65400>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c1ed65828>],
#  'means': []}

# %% [markdown]
# It is observed that all the variables contain outliers, that could be a problem, we could look to make two types of studies based on a threshold that divides these individuals well

# %%
from sklearn import linear_model
X = df.drop('RT',axis=1)
Y = df['RT']

clf = linear_model.LinearRegression()
clf = clf.fit(X,Y)

# %%
# Creamos el objeto de Regresión Linear
regr = linear_model.LinearRegression()
 
# Entrenamos nuestro modelo
regr.fit(X, Y)
 
# Hacemos las predicciones que en definitiva una línea (en este caso, al ser 2D)
y_pred = regr.predict(X)
 
# Veamos los coeficienetes obtenidos, En nuestro caso, serán la Tangente
print('Coefficients: \n', regr.coef_)
# Este es el valor donde corta el eje Y (en X=0)
print('Independent term: \n', regr.intercept_)
# Error Cuadrado Medio
print("Mean squared error: %.2f" % mean_squared_error(Y, y_pred))
# Puntaje de Varianza. El mejor puntaje es un 1.0
print('Variance score: %.2f' % r2_score(Y, y_pred))
# Out:
# Coefficients:
#  [ 2.02449895e+00 -1.17060889e+00 -1.05191270e+00  6.29444768e-01
#   4.21805744e-01 -7.49053597e-15 -2.29083496e-05  2.44252108e-04
#   5.65920796e-04 -4.96132345e-06  4.35755061e-07]
# Independent term:
#  0.06273588144072195
# Mean squared error: 6.78
# Variance score: 0.94

# %%
import statsmodels.formula as smf
import statsmodels as sm
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     RT   R-squared:                       0.940
# Model:                            OLS   Adj. R-squared:                  0.936
# Method:                 Least Squares   F-statistic:                     274.9
# Date:                Thu, 08 Nov 2018   Prob (F-statistic):          8.53e-102
# Time:                        12:41:01   Log-Likelihood:                -441.98
# No. Observations:                 186   AIC:                             904.0
# Df Residuals:                     176   BIC:                             936.2
# Df Model:                          10
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RT_l10               2.0218      0.199     10.168      0.000       1.629       2.414
# sd_RT               -1.1682      0.128     -9.138      0.000      -1.421      -0.916
# FC_l10              -1.0518      0.111     -9.505      0.000      -1.270      -0.833
# sd_FC                0.6285      0.072      8.690      0.000       0.486       0.771
# FC                   0.4235      0.035     12.000      0.000       0.354       0.493
# protected         5.654e-14   6.38e-15      8.866      0.000     4.4e-14    6.91e-14
# followers_count  -2.019e-05   5.57e-05     -0.362      0.717      -0.000    8.97e-05
# friends_count        0.0002      0.000      2.042      0.043    8.27e-06       0.000
# listed_count         0.0005      0.003      0.205      0.838      -0.004       0.005
# favourites_count -4.367e-06   7.18e-06     -0.608      0.544   -1.85e-05     9.8e-06
# statuses_count     7.71e-07   4.53e-06      0.170      0.865   -8.17e-06    9.71e-06
# ==============================================================================
# Omnibus:                      136.854   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2400.803
# Skew:                           2.462   Prob(JB):                         0.00
# Kurtosis:                      19.898   Cond. No.                     6.43e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.18e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X = df.drop('FC',axis=1)
Y = df['FC']
est = sm.OLS(Y, X).fit()
est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     FC   R-squared:                       0.962
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     448.1
# Date:                Thu, 08 Nov 2018   Prob (F-statistic):          1.56e-119
# Time:                        12:41:54   Log-Likelihood:                -527.54
# No. Observations:                 186   AIC:                             1075.
# Df Residuals:                     176   BIC:                             1107.
# Df Model:                          10
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# RT_l10              -1.5212      0.380     -4.004      0.000      -2.271      -0.771
# sd_RT                0.6699      0.241      2.783      0.006       0.195       1.145
# FC_l10               0.7483      0.208      3.595      0.000       0.338       1.159
# sd_FC               -0.2500      0.136     -1.843      0.067      -0.518       0.018
# RT                   1.0626      0.089     12.000      0.000       0.888       1.237
# protected        -4.255e-14      1e-14     -4.240      0.000   -6.24e-14   -2.27e-14
# followers_count  -2.232e-05   8.82e-05     -0.253      0.801      -0.000       0.000
# friends_count        0.0004      0.000      2.235      0.027    5.02e-05       0.001
# listed_count      6.433e-05      0.004      0.016      0.987      -0.008       0.008
# favourites_count -7.336e-07   1.14e-05     -0.064      0.949   -2.32e-05    2.17e-05
# statuses_count   -7.183e-08   7.18e-06     -0.010      0.992   -1.42e-05    1.41e-05
# ==============================================================================
# Omnibus:                      220.964   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12180.050
# Skew:                           4.604   Prob(JB):                         0.00
# Kurtosis:                      41.560   Cond. No.                     1.69e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-25. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
